# %%
library("ggplot2")
library("dplyr")
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_Hum1_all_h38.bed", header = FALSE)

# %%
head(intersect)
# Out:
#   V1   V2      V3      V4 V5   V6      V7      V8           V9       V10
# 1 chr1 1561875 1561876 1  chr1 1560847 1574584 Prepachytene pi-SSU72 13737
# 2 chr1 1561876 1561877 1  chr1 1560847 1574584 Prepachytene pi-SSU72 13737
# 3 chr1 1561877 1561878 1  chr1 1560847 1574584 Prepachytene pi-SSU72 13737
# 4 chr1 1561878 1561879 1  chr1 1560847 1574584 Prepachytene pi-SSU72 13737
# 5 chr1 1561879 1561880 1  chr1 1560847 1574584 Prepachytene pi-SSU72 13737
# 6 chr1 1561880 1561881 1  chr1 1560847 1574584 Prepachytene pi-SSU72 13737

# %%
nrow(intersect)
# Out:
# [1] 1292064

# %%
length(unique(intersect$V9))
# Out:
# [1] 182

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect2<- read.table("intersect_Hum1_all_h38_meanlnc.bed", header = FALSE)

# %%
head(intersect2)
# Out:
#   V1   V2       V3       V4 V5   V6       V7       V8        V9         V10
# 1 chr1 24309628 24309629 3  chr1 24251429 24335724 Pachytene 1-p36-1107 84295
# 2 chr1 24309629 24309630 3  chr1 24251429 24335724 Pachytene 1-p36-1107 84295
# 3 chr1 24309630 24309631 3  chr1 24251429 24335724 Pachytene 1-p36-1107 84295
# 4 chr1 24309631 24309632 3  chr1 24251429 24335724 Pachytene 1-p36-1107 84295
# 5 chr1 24309632 24309633 3  chr1 24251429 24335724 Pachytene 1-p36-1107 84295
# 6 chr1 24309633 24309634 3  chr1 24251429 24335724 Pachytene 1-p36-1107 84295
#   V11  V12      V13      V14
# 1 chr1 24305928 24321901 GRHL3-AS1
# 2 chr1 24305928 24321901 GRHL3-AS1
# 3 chr1 24305928 24321901 GRHL3-AS1
# 4 chr1 24305928 24321901 GRHL3-AS1
# 5 chr1 24305928 24321901 GRHL3-AS1
# 6 chr1 24305928 24321901 GRHL3-AS1

# %%
length(unique(intersect2$V14))
# Out:
# [1] 74

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_lnc_mean_hum1_high_coverage_h38.bed", header = FALSE)

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
nonintersect<- read.table("non_intersect_lnc_mean_hum1_high_coverage_h38.bed", header = FALSE)

# %%
nrow(intersect)
head(intersect)
# Out:
# [1] 676
#   V1   V2        V3        V4           V5   V6        V7        V8   V9
# 1 chr2 110678147 110692786 LOC105373554 chr2 110678556 110678557 2376 chr2
# 2 chr2 110678147 110692786 LOC105373554 chr2 110678557 110678558 2493 chr2
# 3 chr2 110678147 110692786 LOC105373554 chr2 110678558 110678559 2495 chr2
# 4 chr2 110678147 110692786 LOC105373554 chr2 110678559 110678560 2495 chr2
# 5 chr2 110678147 110692786 LOC105373554 chr2 110678560 110678561 2495 chr2
# 6 chr2 110678147 110692786 LOC105373554 chr2 110678561 110678562 2495 chr2
#   V10       V11       V12       V13        V14
# 1 110678284 110716605 Pachytene 2-q13-9453 38321
# 2 110678284 110716605 Pachytene 2-q13-9453 38321
# 3 110678284 110716605 Pachytene 2-q13-9453 38321
# 4 110678284 110716605 Pachytene 2-q13-9453 38321
# 5 110678284 110716605 Pachytene 2-q13-9453 38321
# 6 110678284 110716605 Pachytene 2-q13-9453 38321

# %%
nrow(nonintersect)
head(nonintersect)
# Out:
# [1] 29
#   V1   V2       V3       V4     V5   V6       V7       V8
# 1 chr6 31834916 31839761 SNHG32 chr6 31835262 31835263 23441
# 2 chr6 31834916 31839761 SNHG32 chr6 31835263 31835264 23471
# 3 chr6 31834916 31839761 SNHG32 chr6 31835264 31835265 23480
# 4 chr6 31834916 31839761 SNHG32 chr6 31835265 31835266 23489
# 5 chr6 31834916 31839761 SNHG32 chr6 31835266 31835267 23489
# 6 chr6 31834916 31839761 SNHG32 chr6 31835267 31835268 23489

# %%
table(nonintersect$V4)
# Out:
# SNHG32
#     29

# %%
intersect %>% filter(V4=="SNHG32")
# Out:
#      V1 V2 V3 V4 V5 V6 V7 V8 V9 V10 V11 V12 V13 V14

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_h38_human.bed", header = FALSE)

# %%
head(intersect)
# Out:
#   V1    V2       V3       V4        V5           V6   V7    V8       V9
# 1 chr10 28789400 28795995 Pachytene 10-p11-10777 6595 chr10 28791796 28791797
# 2 chr10 28789400 28795995 Pachytene 10-p11-10777 6595 chr10 28791797 28791798
# 3 chr10 28789400 28795995 Pachytene 10-p11-10777 6595 chr10 28791798 28791799
# 4 chr10 28789400 28795995 Pachytene 10-p11-10777 6595 chr10 28791799 28791800
# 5 chr10 28789400 28795995 Pachytene 10-p11-10777 6595 chr10 28791800 28791801
# 6 chr10 28789400 28795995 Pachytene 10-p11-10777 6595 chr10 28791801 28791802
#   V10
# 1 4832
# 2 4878
# 3 4879
# 4 4879
# 5 4881
# 6 4881

# %%
nrow(intersect %>% distinct(V5))
# Out:
# [1] 21

# %% [markdown]
# # Intersection precursorsHG38 and not annotated testis

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_nonannotated_h38.bed", header = FALSE)

# %%
head(intersect)
# Out:
#   V1   V2        V3        V4          V5   V6   V7        V8
# 1 chr1   1660480   1661552 XLOC_000114 gene chr1   1661478   1692728
# 2 chr1   1668220   1668631 XLOC_000115 gene chr1   1661478   1692728
# 3 chr1   1682393   1682619 XLOC_000117 gene chr1   1661478   1692728
# 4 chr1  24251540  24254842 XLOC_008295 gene chr1  24251429  24335724
# 5 chr1  24302644  24303199 XLOC_008296 gene chr1  24251429  24335724
# 6 chr1 173868168 173868460 XLOC_012220 gene chr1 173868082 173903549
#   V9           V10         V11
# 1 Prepachytene pi-SLC35E2B 31250
# 2 Prepachytene pi-SLC35E2B 31250
# 3 Prepachytene pi-SLC35E2B 31250
# 4 Pachytene    1-p36-1107  84295
# 5 Pachytene    1-p36-1107  84295
# 6 Prepachytene pi-ZBTB37   35467

# %%
table(intersect$V4)
# Out:
# XLOC_000114 XLOC_000115 XLOC_000117 XLOC_008295 XLOC_008296 XLOC_012220
#           1           1           1           1           1           1
# XLOC_012343 XLOC_012344 XLOC_013312 XLOC_013313 XLOC_013314 XLOC_016164
#           1           1           1           1           1           1
# XLOC_016165 XLOC_016452 XLOC_016453 XLOC_016940 XLOC_016941 XLOC_016942
#           1           1           1           2           2           2
# XLOC_016943 XLOC_016945 XLOC_016946 XLOC_016947 XLOC_016948 XLOC_016949
#           2           1           1           1           1           1
# XLOC_016950 XLOC_016951 XLOC_019934 XLOC_019935 XLOC_019940 XLOC_020068
#           1           1           1           1           1           1
# XLOC_020069 XLOC_020130 XLOC_020224 XLOC_020225 XLOC_020226 XLOC_020227
#           1           1           1           1           1           1
# XLOC_020228 XLOC_020229 XLOC_020230 XLOC_020231 XLOC_020232 XLOC_020233
# ...

# %%
intersect %>% filter(V4=="XLOC_016943")
# Out:
#   V1    V2        V3        V4          V5   V6    V7        V8
# 1 chr10 103605714 103606567 XLOC_016943 gene chr10 103493978 103606454
# 2 chr10 103605714 103606567 XLOC_016943 gene chr10 103594026 103855543
#   V9           V10         V11
# 1 Prepachytene pi-NEURL1   112476
# 2 Prepachytene pi-SH3PXD2A 261517

# %% [markdown]
# # Intersection precursorsHG38 and lnc_mean_norm

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_mean_h38.bed", header = FALSE)

# %%
head(intersect)
# Out:
#   V1   V2        V3        V4           V5   V6        V7        V8
# 1 chr1  24305928  24321901 GRHL3-AS1    chr1  24251429  24335724 Pachytene
# 2 chr1 222479518 222499064 LOC105372956 chr1 222471907 222489700 Prepachytene
# 3 chr2  94755326  94761184 FAM95A       chr2  94755423  94857282 Prepachytene
# 4 chr2 110678147 110692786 LOC105373554 chr2 110678284 110716605 Pachytene
# 5 chr2 131402901 131408228 LINC01120    chr2 131402900 131408194 Pachytene
# 6 chr2 238225113 238231677 LINC02610    chr2 238225112 238231651 Pachytene
#   V9            V10
# 1 1-p36-1107     84295
# 2 1-q41-289      17793
# 3 pi-ANKRD20A8P 101859
# 4 2-q13-9453     38321
# 5 2-q21-678       5294
# 6 2-q37-1034      6539

# %%
table(intersect$V4)
# Out:
#    BTBD9-AS1        DGCR5 DKFZp434L192   ELOVL2-AS1      FAM225A      FAM225B
#            1            1            1            1            1            2
#       FAM95A       GHRLOS        GIHCG    GRHL3-AS1    KRT10-AS1    LINC00654
#            1            1            1            1            1            1
#    LINC00661    LINC00668    LINC00837    LINC00865    LINC00904    LINC00905
#            1            1            1            2            1            1
#    LINC00930    LINC00964    LINC01015    LINC01016    LINC01120    LINC01206
#            1            1            1            2            1            1
#    LINC01501    LINC01507    LINC01517    LINC01801    LINC01838    LINC02175
#            1            2            1            1            1            2
#    LINC02222    LINC02367    LINC02610 LOC100506271 LOC100507384 LOC101060187
#            2            1            1            1            1            1
# ...

# %% [markdown]
# # Intersection precursorsHG38 and lnc_prop_exp

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_prop_h38.bed", header = FALSE)

# %%
table(intersect$V4)
# Out:
#        DGCR5 DKFZp434L192   ELOVL2-AS1      FAM225A      FAM225B       FAM95A
#            1            1            1            1            2            1
#        GIHCG    KRT10-AS1    LINC00654    LINC00661    LINC00668    LINC00674
#            1            1            1            1            1            1
#    LINC00837    LINC00865    LINC00904    LINC00905    LINC00964    LINC01016
#            1            2            1            1            1            2
#    LINC01206    LINC01501    LINC01507    LINC01517    LINC01572    LINC02367
#            1            1            2            1            1            1
#    LINC02610 LOC101927060 LOC101927978 LOC101928030 LOC102724938 LOC105369649
#            1            1            2            1            1            1
# LOC105370612 LOC105370982 LOC105373554 LOC105375044 LOC105376101 LOC105376107
#            1            1            1            1            1            1
# ...

# %%
ggplot(intersect, aes(x=V4, fill=V1))+
    geom_histogram(binwidth=.8, stat="count")+
    coord_flip() +
    ggtitle("Intersection of precursors hg38 and lnc_prop_exp")+
    labs(y = "Counts", x = "Type of lncRNA")
# Out:
# Warning message in geom_histogram(binwidth = 0.8, stat = "count"):
# “Ignoring unknown parameters: `binwidth`, `bins`, and `pad`”
# plot without title

# %% [markdown]
# # Intersect human unique reads and high coverage with precursorsHG38 and non_annotated_testis

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_h38_human_nonannotated.bed", header = FALSE)
head(intersect)
# Out:
#   V1    V2       V3       V4        V5           V6    V7    V8       V9
# 1 chr10 77763999 77783913 Pachytene 10-q22-16903 19914 chr10 77767276 77767277
# 2 chr10 77763999 77783913 Pachytene 10-q22-16903 19914 chr10 77767276 77767277
# 3 chr10 77763999 77783913 Pachytene 10-q22-16903 19914 chr10 77767276 77767277
# 4 chr10 77763999 77783913 Pachytene 10-q22-16903 19914 chr10 77767276 77767277
# 5 chr10 77763999 77783913 Pachytene 10-q22-16903 19914 chr10 77767276 77767277
# 6 chr10 77763999 77783913 Pachytene 10-q22-16903 19914 chr10 77767277 77767278
#   V10  V11   V12      V13      V14         V15
# 1 1625 chr10 77763960 77766321 XLOC_016164 gene
# 2 1625 chr10 77766383 77773595 XLOC_016165 gene
# 3 1625 chr10 77772987 77773337 XLOC_019934 gene
# 4 1625 chr10 77773413 77773663 XLOC_019935 gene
# 5 1625 chr10 77782080 77782725 XLOC_019940 gene
# 6 1657 chr10 77763960 77766321 XLOC_016164 gene

# %%
table(intersect$V14)
# Out:
# XLOC_016164 XLOC_016165 XLOC_019934 XLOC_019935 XLOC_019940 XLOC_026627
#          51          51          51          51          51          31
# XLOC_026629 XLOC_026630 XLOC_026631 XLOC_026632 XLOC_026633 XLOC_026634
#          31          31          31          31          31          31
# XLOC_026635 XLOC_026636 XLOC_026637 XLOC_026638 XLOC_026639 XLOC_026640
#          31          31          31          31          31          31
# XLOC_043432 XLOC_047836 XLOC_047837 XLOC_048152 XLOC_048153 XLOC_048154
#          29          20          20          28          28          28
# XLOC_048155 XLOC_048156 XLOC_048157 XLOC_048158 XLOC_048159 XLOC_048160
#          56          56          56          56          56          56
# XLOC_048161 XLOC_048162 XLOC_048163 XLOC_048164 XLOC_048165 XLOC_048166
#          56          56          56          56          56          56
# XLOC_048167 XLOC_048168 XLOC_048169 XLOC_048170 XLOC_048171 XLOC_048172
# ...

# %%
ggplot(intersect, aes(x=V14, fill=V1))+
    geom_histogram(binwidth=.8, stat="count")+
    coord_flip() +
    ggtitle("Intersection of precursors hg38 and human high coverage and non_annotated_testis")+
    labs(y = "Counts", x = "Type of lncRNA")
# Out:
# Warning message in geom_histogram(binwidth = 0.8, stat = "count"):
# “Ignoring unknown parameters: `binwidth`, `bins`, and `pad`”
# plot without title

# %% [markdown]
# # Intersect human unique reads and high coverage with precursorsHG38 and lnc_mean_norm

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_h38_human_mean.bed", header = FALSE)
head(intersect)
# Out:
#   V1    V2       V3       V4        V5           V6   V7    V8       V9
# 1 chr10 28789400 28795995 Pachytene 10-p11-10777 6595 chr10 28791796 28791797
# 2 chr10 28789400 28795995 Pachytene 10-p11-10777 6595 chr10 28791796 28791797
# 3 chr10 28789400 28795995 Pachytene 10-p11-10777 6595 chr10 28791797 28791798
# 4 chr10 28789400 28795995 Pachytene 10-p11-10777 6595 chr10 28791797 28791798
# 5 chr10 28789400 28795995 Pachytene 10-p11-10777 6595 chr10 28791798 28791799
# 6 chr10 28789400 28795995 Pachytene 10-p11-10777 6595 chr10 28791798 28791799
#   V10  V11   V12      V13      V14
# 1 4832 chr10 28789311 28796050 LINC00837
# 2 4832 chr10 28743650 28808219 LINC01517
# 3 4878 chr10 28789311 28796050 LINC00837
# 4 4878 chr10 28743650 28808219 LINC01517
# 5 4879 chr10 28789311 28796050 LINC00837
# 6 4879 chr10 28743650 28808219 LINC01517

# %%
table(intersect$V14)
# Out:
#       GHRLOS    LINC00837    LINC00904    LINC00905    LINC01015    LINC01016
#           26           54           29          118           56           96
#    LINC01507    LINC01517    LINC01801    LINC01838 LOC100506271 LOC101060187
#           26           54           58           63          104           28
# LOC102724938 LOC105370613 LOC105370850 LOC105372377 LOC105373554 LOC105375026
#           56           29           56           92           28           52
# LOC105375027 LOC105376100 LOC105376101 LOC107984784        TDRG1
#           44           26           26           28          202

# %%
ggplot(intersect, aes(x=V14, fill=V1))+
    geom_histogram(binwidth=.8, stat="count")+
    coord_flip() +
    ggtitle("Intersection of precursors hg38 and high coverage huan and lnc_mean_norm")+
    labs(y = "Counts", x = "Type of lncRNA")
# Out:
# Warning message in geom_histogram(binwidth = 0.8, stat = "count"):
# “Ignoring unknown parameters: `binwidth`, `bins`, and `pad`”
# plot without title

# %% [markdown]
# # Intersect human unique reads and high coverage with precursorsHG38 and lnc_prop_exp

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_h38_human_prop.bed", header = FALSE)
head(intersect)
# Out:
#   V1    V2       V3       V4        V5           V6   V7    V8       V9
# 1 chr10 28789400 28795995 Pachytene 10-p11-10777 6595 chr10 28791796 28791797
# 2 chr10 28789400 28795995 Pachytene 10-p11-10777 6595 chr10 28791796 28791797
# 3 chr10 28789400 28795995 Pachytene 10-p11-10777 6595 chr10 28791797 28791798
# 4 chr10 28789400 28795995 Pachytene 10-p11-10777 6595 chr10 28791797 28791798
# 5 chr10 28789400 28795995 Pachytene 10-p11-10777 6595 chr10 28791798 28791799
# 6 chr10 28789400 28795995 Pachytene 10-p11-10777 6595 chr10 28791798 28791799
#   V10  V11   V12      V13      V14
# 1 4832 chr10 28789311 28796050 LINC00837
# 2 4832 chr10 28743650 28808219 LINC01517
# 3 4878 chr10 28789311 28796050 LINC00837
# 4 4878 chr10 28743650 28808219 LINC01517
# 5 4879 chr10 28789311 28796050 LINC00837
# 6 4879 chr10 28743650 28808219 LINC01517

# %%
table(intersect$V14)
# Out:
#    LINC00837    LINC00904    LINC00905    LINC01016    LINC01507    LINC01517
#           54           29          118           96           26           54
# LOC102724938 LOC105373554 LOC105376101        TDRG1
#           56           28           26          202

# %%
ggplot(intersect, aes(x=V14, fill=V1))+
    geom_histogram(binwidth=.8, stat="count")+
    coord_flip() +
    ggtitle("Intersection of precursors hg38 and high coverage human and lnc_prop_expr")+
    labs(y = "Counts", x = "Type of lncRNA")
# Out:
# Warning message in geom_histogram(binwidth = 0.8, stat = "count"):
# “Ignoring unknown parameters: `binwidth`, `bins`, and `pad`”
# plot without title

# %% [markdown]
# # Intersect human unique reads and high coverage with precursorsHG19 and lnc_prop_exp

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_h19_human_prop.bed", header = FALSE)
# Out:
# Error in read.table("intersect_h19_human_prop.bed", header = FALSE): no lines available in input
# Traceback:
#
# 1. read.table("intersect_h19_human_prop.bed", header = FALSE)
# 2. stop("no lines available in input")

# %% [markdown]
# # Intersect all precursors and not_annotated_testis

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersection_precursors_notannotated.bed", header = FALSE)
head(intersect)
# Out:
#   V1   V2        V3        V4            V5   V6        V7        V8
# 1 chr1   1661478   1692728 pi-SLC35E2B.1 chr1   1660480   1661552 XLOC_000114
# 2 chr1   1661478   1692728 pi-SLC35E2B.1 chr1   1668220   1668631 XLOC_000115
# 3 chr1   1661478   1692728 pi-SLC35E2B.1 chr1   1682393   1682619 XLOC_000117
# 4 chr1  24251429  24335724 1-p36-1107.1  chr1  24251540  24254842 XLOC_008295
# 5 chr1  24251429  24335724 1-p36-1107.1  chr1  24302644  24303199 XLOC_008296
# 6 chr1 173868082 173886636 pi-ZBTB37.2   chr1 173868168 173868460 XLOC_012220
#   V9
# 1 transcript
# 2 transcript
# 3 transcript
# 4 transcript
# 5 transcript
# 6 transcript

# %%
table(intersect$V8)
# Out:
# XLOC_000099 XLOC_000100 XLOC_000101 XLOC_000102 XLOC_000105 XLOC_000106
#           1           1           1           2           1           1
# XLOC_000107 XLOC_000108 XLOC_000114 XLOC_000115 XLOC_000117 XLOC_005135
#           1           1           1           1           1           1
# XLOC_007282 XLOC_007286 XLOC_007287 XLOC_007288 XLOC_007289 XLOC_008295
#           1           1           1           1           1           1
# XLOC_008296 XLOC_008305 XLOC_008307 XLOC_008308 XLOC_008309 XLOC_008310
#           1           1           1           1           1           1
# XLOC_008311 XLOC_008312 XLOC_008313 XLOC_008314 XLOC_008315 XLOC_008316
#           1           1           1           1           1           1
# XLOC_011117 XLOC_012217 XLOC_012218 XLOC_012220 XLOC_012343 XLOC_012344
#           1           2           2           3           1           1
# XLOC_013312 XLOC_013313 XLOC_013314 XLOC_013327 XLOC_013329 XLOC_016164
# ...

# %% [markdown]
# # Intersect all precursors and lnc_mean_norm

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_precursors_mean.bed", header = FALSE)
head(intersect)
# Out:
#   V1    V2        V3        V4             V5    V6        V7
# 1 chr1   24251429  24335724 1-p36-1107.1   chr1   24305928  24321901
# 2 chr1  222471907 222489700 1-q41-289.1    chr1  222479518 222499064
# 3 chr10  28789400  28795995 10-p11-10777.1 chr10  28789311  28796050
# 4 chr10  28789400  28795995 10-p11-10777.1 chr10  28743650  28808219
# 5 chr10  28789400  28795995 10-p11-10777.2 chr10  28789311  28796050
# 6 chr10  28789400  28795995 10-p11-10777.2 chr10  28743650  28808219
#   V8
# 1 GRHL3-AS1
# 2 LOC105372956
# 3 LINC00837
# 4 LINC01517
# 5 LINC00837
# 6 LINC01517

# %%
table(intersect$V8)
# Out:
#     BTBD9-AS1 CCDC144NL-AS1         DGCR5  DKFZp434L192    ELOVL2-AS1
#             2             1             2             1             4
#       FAM225A       FAM225B        FAM95A        GHRLOS         GIHCG
#             2             3             2             2             3
#     GRHL3-AS1    HECTD2-AS1     KRT10-AS1     LINC00654     LINC00661
#             1             4             2             1             3
#     LINC00668     LINC00837     LINC00865     LINC00904     LINC00905
#             4             3             4             1             2
#     LINC00930     LINC00964     LINC01015     LINC01016     LINC01120
#             1             3             2             2             1
#     LINC01206     LINC01501     LINC01507     LINC01517     LINC01801
#             2             1             2             3             1
#     LINC01838     LINC01993     LINC02175     LINC02222     LINC02333
# ...

# %% [markdown]
# # Intersect all precursors and prop_exp

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_precursors_prop.bed", header = FALSE)
head(intersect)
# Out:
#   V1    V2       V3       V4             V5    V6       V7       V8
# 1 chr10 28789400 28795995 10-p11-10777.1 chr10 28789311 28796050 LINC00837
# 2 chr10 28789400 28795995 10-p11-10777.1 chr10 28743650 28808219 LINC01517
# 3 chr10 28789400 28795995 10-p11-10777.2 chr10 28789311 28796050 LINC00837
# 4 chr10 28789400 28795995 10-p11-10777.2 chr10 28743650 28808219 LINC01517
# 5 chr10 28789400 28795995 10-p11-10777.3 chr10 28789311 28796050 LINC00837
# 6 chr10 28789400 28795995 10-p11-10777.3 chr10 28743650 28808219 LINC01517

# %%
table(intersect$V8)
# Out:
# CCDC144NL-AS1         DGCR5  DKFZp434L192    ELOVL2-AS1       FAM225A
#             1             2             1             4             2
#       FAM225B        FAM95A         GIHCG    HECTD2-AS1     KRT10-AS1
#             3             2             3             4             2
#     LINC00654     LINC00661     LINC00668     LINC00674     LINC00837
#             1             3             4             1             3
#     LINC00865     LINC00904     LINC00905     LINC00964     LINC01016
#             4             1             2             3             2
#     LINC01206     LINC01501     LINC01507     LINC01517     LINC01572
#             2             1             2             3             1
#     LINC02367     LINC02610  LOC101927060  LOC101927978  LOC101928030
#             3             2             1             6             2
#  LOC102724938  LOC105369649  LOC105370032  LOC105370612  LOC105370974
# ...

# %% [markdown]
# # Intersection all precursors with high coverage human and not_annotated_testis

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_precursors_human_notannotated.bed", header = FALSE)
head(intersect)
# Out:
#   V1    V2       V3       V4             V5    V6       V7       V8
# 1 chr10 77767276 77767277 10-q22-16903.1 chr10 77766383 77773595 XLOC_016165
# 2 chr10 77767277 77767278 10-q22-16903.1 chr10 77766383 77773595 XLOC_016165
# 3 chr10 77767278 77767279 10-q22-16903.1 chr10 77766383 77773595 XLOC_016165
# 4 chr10 77767279 77767280 10-q22-16903.1 chr10 77766383 77773595 XLOC_016165
# 5 chr10 77767280 77767281 10-q22-16903.1 chr10 77766383 77773595 XLOC_016165
# 6 chr10 77767281 77767282 10-q22-16903.1 chr10 77766383 77773595 XLOC_016165
#   V9
# 1 transcript
# 2 transcript
# 3 transcript
# 4 transcript
# 5 transcript
# 6 transcript

# %%
    table(intersect$V8)
# Out:
# XLOC_016165 XLOC_026631 XLOC_026638 XLOC_048161 XLOC_048165 XLOC_050546
#          51           8          54          29          27          20
# XLOC_050853 XLOC_070925 XLOC_080650 XLOC_151013
#          28         182          28          27

# %%
ggplot(intersect, aes(x=V8, fill=V1))+
    geom_histogram(binwidth=.8, stat="count")+
    coord_flip() +
    ggtitle("Intersection of all precursors and high coverage human and not_annotated_testis")+
    labs(y = "Counts", x = "Type of lncRNA")
# Out:
# Warning message in geom_histogram(binwidth = 0.8, stat = "count"):
# “Ignoring unknown parameters: `binwidth`, `bins`, and `pad`”
# plot without title

# %% [markdown]
# # Intersection all precursors with high coverage human and lnc_mean_norm

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_precursors_human_mean.bed", header = FALSE)
head(intersect)
# Out:
#   V1    V2       V3       V4             V5    V6       V7       V8
# 1 chr10 28791796 28791797 10-p11-10777.1 chr10 28789311 28796050 LINC00837
# 2 chr10 28791796 28791797 10-p11-10777.1 chr10 28743650 28808219 LINC01517
# 3 chr10 28791797 28791798 10-p11-10777.1 chr10 28789311 28796050 LINC00837
# 4 chr10 28791797 28791798 10-p11-10777.1 chr10 28743650 28808219 LINC01517
# 5 chr10 28791798 28791799 10-p11-10777.1 chr10 28789311 28796050 LINC00837
# 6 chr10 28791798 28791799 10-p11-10777.1 chr10 28743650 28808219 LINC01517

# %%
    table(intersect$V8)
# Out:
#    LINC00837    LINC00905    LINC01015    LINC01016    LINC01507    LINC01517
#          162          236          112           28           26          162
#    LINC01838 LOC101060187 LOC105372377 LOC105373554 LOC105375026 LOC105376101
#           63           56           36           28           52           26
#        TDRG1
#          404

# %%
ggplot(intersect, aes(x=V8, fill=V1))+
    geom_histogram(binwidth=.8, stat="count")+
    coord_flip() +
    ggtitle("Intersection of all precursors and high coverage human and mean_norm")+
    labs(y = "Counts", x = "Type of lncRNA")
# Out:
# Warning message in geom_histogram(binwidth = 0.8, stat = "count"):
# “Ignoring unknown parameters: `binwidth`, `bins`, and `pad`”
# plot without title

# %% [markdown]
# # Intersection all precursors with high coverage human and lnc_prop_exp

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_precursors_human_prop.bed", header = FALSE)
head(intersect)
# Out:
#   V1    V2       V3       V4             V5    V6       V7       V8
# 1 chr10 28791796 28791797 10-p11-10777.1 chr10 28789311 28796050 LINC00837
# 2 chr10 28791796 28791797 10-p11-10777.1 chr10 28743650 28808219 LINC01517
# 3 chr10 28791797 28791798 10-p11-10777.1 chr10 28789311 28796050 LINC00837
# 4 chr10 28791797 28791798 10-p11-10777.1 chr10 28743650 28808219 LINC01517
# 5 chr10 28791798 28791799 10-p11-10777.1 chr10 28789311 28796050 LINC00837
# 6 chr10 28791798 28791799 10-p11-10777.1 chr10 28743650 28808219 LINC01517

# %%
    table(intersect$V8)
# Out:
#    LINC00837    LINC00905    LINC01016    LINC01507    LINC01517 LOC105373554
#          162          236           28           26          162           28
# LOC105376101        TDRG1
#           26          404

# %%
head(intersect)
# Out:
#   V1    V2       V3       V4
# 1 chr10 28791796 28791797 10-p11-10777.1
# 2 chr10 28791796 28791797 10-p11-10777.1
# 3 chr10 28791797 28791798 10-p11-10777.1
# 4 chr10 28791797 28791798 10-p11-10777.1
# 5 chr10 28791798 28791799 10-p11-10777.1
# 6 chr10 28791798 28791799 10-p11-10777.1

# %%
ggplot(intersect, aes(x=V8, fill=V1))+
    geom_histogram(binwidth=.8, stat="count")+
    coord_flip() +
    ggtitle("Intersection of all precursors and high coverage human and prop_exp")+
    labs(y = "Counts", x = "Type of lncRNA")
# Out:
# Warning message in geom_histogram(binwidth = 0.8, stat = "count"):
# “Ignoring unknown parameters: `binwidth`, `bins`, and `pad`”
# plot without title

# %% [markdown]
# # Intersection precursorsHG19 and lnc_mean_norm

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_mean_precursorsh19.bed", header = FALSE)

# %%
table(intersect$V4)
# Out:
#     BTBD9-AS1 CCDC144NL-AS1         DGCR5    ELOVL2-AS1        GHRLOS
#             1             1             1             2             1
#    HECTD2-AS1     LINC00668     LINC01993     LINC02333  LOC100287896
#             4             2             1             2             1
#  LOC100507384  LOC101927025  LOC101927978  LOC105369594  LOC105370032
#             1             2             3             1             4
#  LOC105370974  LOC105371064  LOC105375027  LOC107985411  LOC107987087
#             1             2             2             1             2
#     LOC400541     LOC643406     LOC728196        SNHG14       SOX2-OT
#             2             1             1             1             2
#   ZKSCAN7-AS1
#             2

# %%
ggplot(intersect, aes(x=V4, fill=V1))+
    geom_histogram(binwidth=.8, stat="count")+
    coord_flip() +
    ggtitle("Intersection of precursors hg19 and lnc_mean_norm")+
    labs(y = "Counts", x = "Type of lncRNA")
# Out:
# Warning message in geom_histogram(binwidth = 0.8, stat = "count"):
# “Ignoring unknown parameters: `binwidth`, `bins`, and `pad`”
# plot without title

# %% [markdown]
# # Intersection precursorsHG19 and not annotated testis

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_notannotated_precursorshg19.bed", header = FALSE)

# %%
table(intersect$V4)
# Out:
# XLOC_000099 XLOC_000100 XLOC_000101 XLOC_000102 XLOC_000105 XLOC_000106
#           1           1           1           2           1           1
# XLOC_000107 XLOC_000108 XLOC_005135 XLOC_007282 XLOC_007286 XLOC_007287
#           1           1           1           1           1           1
# XLOC_007288 XLOC_007289 XLOC_008305 XLOC_008307 XLOC_008308 XLOC_008309
#           1           1           1           1           1           1
# XLOC_008310 XLOC_008311 XLOC_008312 XLOC_008313 XLOC_008314 XLOC_008315
#           1           1           1           1           1           1
# XLOC_008316 XLOC_011117 XLOC_012217 XLOC_012218 XLOC_012220 XLOC_013327
#           1           1           2           2           1           1
# XLOC_013329 XLOC_016235 XLOC_016236 XLOC_016237 XLOC_016435 XLOC_016998
#           1           1           1           1           1           1
# XLOC_016999 XLOC_017000 XLOC_017001 XLOC_017002 XLOC_017003 XLOC_020189
# ...

# %% [markdown]
# # Intersection precursorsHG19 and lnc_prop_exp

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_prop_precursorshg19.bed", header = FALSE)

# %%
table(intersect$V4)
# Out:
# CCDC144NL-AS1         DGCR5    ELOVL2-AS1    HECTD2-AS1     LINC00668
#             1             1             2             4             2
#  LOC101927978  LOC105370032  LOC105370974  LOC107987087     LOC643406
#             3             4             1             2             1
#        SNHG14       SOX2-OT   ZKSCAN7-AS1
#             1             2             2

# %%
ggplot(intersect, aes(x=V4, fill=V1))+
    geom_histogram(binwidth=.8, stat="count")+
    coord_flip() +
    ggtitle("Intersection of precursors hg19 and lnc_prop_exp")+
    labs(y = "Counts", x = "Type of lncRNA")
# Out:
# Warning message in geom_histogram(binwidth = 0.8, stat = "count"):
# “Ignoring unknown parameters: `binwidth`, `bins`, and `pad`”
# plot without title

# %% [markdown]
# # Intersect human unique reads and high coverage with precursorsHG19 and non_annotated_testis

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_h19_human_nonannotated.bed", header = FALSE)
head(intersect)
# Out:
#   V1    V2       V3       V4             V5    V6       V7       V8
# 1 chr11 45701084 45701085 11-p11-43732.1 chr11 45699009 45701569 XLOC_026631
# 2 chr11 45701085 45701086 11-p11-43732.1 chr11 45699009 45701569 XLOC_026631
# 3 chr11 45701086 45701087 11-p11-43732.1 chr11 45699009 45701569 XLOC_026631
# 4 chr11 45701087 45701088 11-p11-43732.1 chr11 45699009 45701569 XLOC_026631
# 5 chr11 45713137 45713138 11-p11-43732.1 chr11 45711826 45715204 XLOC_026638
# 6 chr11 45713138 45713139 11-p11-43732.1 chr11 45711826 45715204 XLOC_026638
#   V9
# 1 transcript
# 2 transcript
# 3 transcript
# 4 transcript
# 5 transcript
# 6 transcript

# %%
table(intersect$V8)
# Out:
# XLOC_026631 XLOC_026638
#           4          27

# %%
ggplot(intersect, aes(x=V8, fill=V1))+
    geom_histogram(binwidth=.8, stat="count")+
    coord_flip() +
    ggtitle("Intersection of precursors hg19 and high_coverage human and non_annotated_testis")+
    labs(y = "Counts", x = "Type of lncRNA")
# Out:
# Warning message in geom_histogram(binwidth = 0.8, stat = "count"):
# “Ignoring unknown parameters: `binwidth`, `bins`, and `pad`”
# plot without title

# %% [markdown]
# # Intersect human unique reads and high coverage with precursorsHG19 and lnc_mean_norm

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_h19_human_mean.bed", header = FALSE)
# Out:
# Error in read.table("intersect_h19_human_mean.bed", header = FALSE): no lines available in input
# Traceback:
#
# 1. read.table("intersect_h19_human_mean.bed", header = FALSE)
# 2. stop("no lines available in input")

# %% [markdown]
# # Intersection unique A1 coverage and precursors

# %%
setwd("~/piRNA/Workspaces/julia/zamore_lab/coverage_unique/A1")
A1<- read.table("A1_coverage", header=FALSE)

# %%
#chromosome data
setwd("~/piRNA/Workspaces/julia/PrimaryData/ref_data/human")
chromosome_data<- read.table("summary_chroms.tsv", header=TRUE)

# %%
names(A1)[names(A1) == "V1"]<- "REFSEQ_CHROM"
unique_data<- merge(A1, chromosome_data, by= "REFSEQ_CHROM")

# %%
head(unique_data)
# Out:
#   UCSC_CHROM pos   V2    V3
# 1 chr1       16216 16217 1
# 2 chr1       16217 16218 1
# 3 chr1       16218 16219 1
# 4 chr1       16219 16220 1
# 5 chr1       16220 16221 1
# 6 chr1       16221 16222 1

# %%
unique_data$pos<- unique_data$V2 - 1

# %%
unique_data<- unique_data[,c(5,7,2,3)]

# %%
options(scipen = 99999)

# %%
setwd("~/piRNA/Workspaces/julia/zamore_lab/coverage_unique/A1")
write.table(unique_data, file = "A1_coverage_unique.bed", quote=FALSE, sep="\t", row.names = FALSE, col.names=FALSE)

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_A1_unique_h38.bed", header = FALSE)

# %%
head(intersect)
# Out:
#   V1   V2      V3      V4 V5   V6      V7      V8           V9       V10
# 1 chr1 1560847 1560848 1  chr1 1560847 1574584 Prepachytene pi-SSU72 13737
# 2 chr1 1560848 1560849 1  chr1 1560847 1574584 Prepachytene pi-SSU72 13737
# 3 chr1 1560849 1560850 1  chr1 1560847 1574584 Prepachytene pi-SSU72 13737
# 4 chr1 1560850 1560851 1  chr1 1560847 1574584 Prepachytene pi-SSU72 13737
# 5 chr1 1560851 1560852 1  chr1 1560847 1574584 Prepachytene pi-SSU72 13737
# 6 chr1 1560852 1560853 1  chr1 1560847 1574584 Prepachytene pi-SSU72 13737
#   len_precursor len_read
# 1 13737         1
# 2 13737         1
# 3 13737         1
# 4 13737         1
# 5 13737         1
# 6 13737         1

# %%
nrow(intersect)
# Out:
# [1] 2802226

# %%
length(unique(intersect$V9))
# Out:
# [1] 182

# %% [markdown]
# There are a total of 182 precursors and all them overlap at least once with a position

# %% [markdown]
# # Intersection A1 unique and h38 and not annotated testis

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_A1_unique_h38_nonannotated.bed", header=FALSE)

# %%
head(intersect)
# Out:
#   V1   V2      V3      V4 V5   V6      V7      V8           V9          V10
# 1 chr1 1661478 1661479 1  chr1 1661478 1692728 Prepachytene pi-SLC35E2B 31250
# 2 chr1 1668220 1668221 1  chr1 1661478 1692728 Prepachytene pi-SLC35E2B 31250
# 3 chr1 1668221 1668222 1  chr1 1661478 1692728 Prepachytene pi-SLC35E2B 31250
# 4 chr1 1668222 1668223 1  chr1 1661478 1692728 Prepachytene pi-SLC35E2B 31250
# 5 chr1 1668430 1668431 1  chr1 1661478 1692728 Prepachytene pi-SLC35E2B 31250
# 6 chr1 1668431 1668432 1  chr1 1661478 1692728 Prepachytene pi-SLC35E2B 31250
#   V11  V12     V13     V14         V15
# 1 chr1 1660480 1661552 XLOC_000114 gene
# 2 chr1 1668220 1668631 XLOC_000115 gene
# 3 chr1 1668220 1668631 XLOC_000115 gene
# 4 chr1 1668220 1668631 XLOC_000115 gene
# 5 chr1 1668220 1668631 XLOC_000115 gene
# 6 chr1 1668220 1668631 XLOC_000115 gene

# %%
length(unique(intersect$V9))
# Out:
# [1] 125

# %% [markdown]
# there are a total of 125 different precursors that are overlapping with positions that are annotated

# %%
#create a dataframe just with the different precursors taking the position with higher coverage
intersect_unique <- intersect %>%
    group_by(V9) %>%
    slice(which.max(V4))

# %%
nrow(unique_df)
# Out:
# [1] 125

# %% [markdown]
# there is a total of 125 different precursors that overlap with a position that is annotated

# %% [markdown]
# # Concatenate the annotations

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
mean<- read.table("lnc_mean_norm.bed", header=FALSE)
head(mean)
nrow(mean)
# Out:
#   V1   V2      V3      V4
# 1 chr1   29926   31295 MIR1302-2HG
# 2 chr1   34611   36081 FAM138A
# 3 chr1  200442  203983 LOC107985721
# 4 chr1 1399530 1402046 MRPL20-AS1
# 5 chr1 1745725 1751773 LOC112268218
# 6 chr1 1891180 1892726 LOC105378949
# [1] 3017

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
prop<- read.table("lnc_prop_exp.bed", header=FALSE)
head(prop)
nrow(prop)
# Out:
#   V1   V2       V3       V4
# 1 chr1    89006   267354 LOC100996442
# 2 chr1  3059617  3067725 PRDM16-DT
# 3 chr1  8878835  8879885 ENO1-AS1
# 4 chr1 19210386 19240704 EMC1-AS1
# 5 chr1 19860211 19889289 LOC105376823
# 6 chr1 35358822 35366077 ZMYM4-AS1
# [1] 870

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
not<- read.table("not_annotated_testis.bed", header=FALSE)
not<-not[,c(1,2,3,4)]
head(not)
nrow(not)
# Out:
#   V1   V2     V3     V4
# 1 chr1 180884 181110 XLOC_000007
# 2 chr1 268297 268582 XLOC_000009
# 3 chr1 824435 825064 XLOC_000022
# 4 chr1 863337 863780 XLOC_000024
# 5 chr1 890777 890985 XLOC_000026
# 6 chr1 890998 891324 XLOC_000027
# [1] 98189

# %%
annotations<-rbind(mean,prop,not)
nrow(annotations)
# Out:
# [1] 102076

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
write.table(annotations, file = "all.bed", quote=FALSE, sep="\t", row.names = FALSE, col.names=FALSE)

# %% [markdown]
# # Intersect A1 unique and h38 with all annotations

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_A1_h38_all.bed", header=FALSE)

# %%
head(intersect)
# Out:
#   V1   V2      V3      V4 V5   V6      V7      V8           V9          V10
# 1 chr1 1661478 1661479 1  chr1 1661478 1692728 Prepachytene pi-SLC35E2B 31250
# 2 chr1 1668220 1668221 1  chr1 1661478 1692728 Prepachytene pi-SLC35E2B 31250
# 3 chr1 1668221 1668222 1  chr1 1661478 1692728 Prepachytene pi-SLC35E2B 31250
# 4 chr1 1668222 1668223 1  chr1 1661478 1692728 Prepachytene pi-SLC35E2B 31250
# 5 chr1 1668430 1668431 1  chr1 1661478 1692728 Prepachytene pi-SLC35E2B 31250
# 6 chr1 1668431 1668432 1  chr1 1661478 1692728 Prepachytene pi-SLC35E2B 31250
#   V11  V12     V13     V14
# 1 chr1 1660480 1661552 XLOC_000114
# 2 chr1 1668220 1668631 XLOC_000115
# 3 chr1 1668220 1668631 XLOC_000115
# 4 chr1 1668220 1668631 XLOC_000115
# 5 chr1 1668220 1668631 XLOC_000115
# 6 chr1 1668220 1668631 XLOC_000115

# %%
length(unique(intersect$V9))
# Out:
# [1] 152

# %%
table(intersect$V14)
# Out:
#    BTBD9-AS1        DGCR5 DKFZp434L192   ELOVL2-AS1      FAM225A      FAM225B
#          335        11412         2010         4964         1104         1072
#       FAM95A       GHRLOS        GIHCG    GRHL3-AS1    KRT10-AS1    LINC00654
#         8114          256         2602         1104         4772        11002
#    LINC00661    LINC00668    LINC00674    LINC00837    LINC00865    LINC00904
#        15598         5572        14460         9100        24972         1092
#    LINC00905    LINC00930    LINC00964    LINC01015    LINC01016    LINC01120
#        13638         3983        14228         3659        13016         2719
#    LINC01206    LINC01501    LINC01507    LINC01517    LINC01572    LINC01801
#        20918         3564        85818         9100          147         2594
#    LINC01838    LINC02175    LINC02222    LINC02367    LINC02610 LOC100506271
#         1913         3104         1994        20470         4884         2622
# ...

# %%
intersect_unique <- intersect %>%
    group_by(V9) %>%
    slice(which.max(V4))

# %%
df_sorted <- arrange(intersect_unique, desc(V4))
head(df_sorted)
nrow(df_sorted)
# Out:
#   V1    V2       V3       V4    V5    V6       V7       V8        V9
# 1 chr15 62239094 62239095 80456 chr15 62223875 62282161 Pachytene 15-q22-56093
# 2 chr6  33900489 33900490 43790 chr6  33893163 33918208 Pachytene 6-p21-43244
# 3 chr15 62221785 62221786 33982 chr15 62196008 62224182 Pachytene 15-q22-8218
# 4 chr6  40378446 40378447 30840 chr6  40378336 40379885 Pachytene pi-TDRG1
# 5 chr19 16037964 16037965 29038 chr19 16033653 16041254 Pachytene 19-p13-25455
# 6 chr15 51292059 51292060 25484 chr15 51248620 51303101 Pachytene pi-CYP19A1
#   V10   V11   V12      V13      V14
# 1 58286 chr15 62235199 62242840 XLOC_048161
# 2 25045 chr6  33893093 33914794 LOC105375026
# 3 28174 chr15 62219310 62224142 XLOC_050853
# 4  1549 chr6  40378337 40379893 TDRG1
# 5  7601 chr19 16033713 16042135 LINC00905
# 6 54481 chr15 51289323 51293682 XLOC_050546
# [1] 152

# %%
cbPalette <- c("#56B4E9", "#E69F00",  "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7")
ggplot(intersect_unique, aes(V3,V4))+
    geom_line()+
    geom_point(aes(x=as.numeric(V6),y=-1000,colour=factor(V8)),size=2)+
    theme_minimal()+
    scale_colour_manual(name="Variables",values=cbPalette)
# Out:
# plot without title

# %%
filtered_df <- subset(intersect_unique, intersect_unique[, 8] == "Pachytene")
cbPalette <- c( "#E69F00",  "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7")
ggplot(filtered_df, aes(V3,V4))+
    geom_line()+
    geom_point(aes(x=as.numeric(V6),y=-1000,colour=factor(V8)),size=1.5)+
    theme_minimal()+
    scale_colour_manual(name="Variables",values=cbPalette)
# Out:
# plot without title

# %% [markdown]
# # Intersect A1 and precursors (maintain all rows)

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_A1_h38_NA.bed", header=FALSE)

# %%
length(unique(intersect$V9))
# Out:
# [1] 183

# %%
head(intersect)
# Out:
#   V1   V2    V3    V4 V5 V6 V7 V8 V9 V10 ov_non
# 1 chr1 16216 16217 1  .  -1 -1 .  .  .   0
# 2 chr1 16217 16218 1  .  -1 -1 .  .  .   0
# 3 chr1 16218 16219 1  .  -1 -1 .  .  .   0
# 4 chr1 16219 16220 1  .  -1 -1 .  .  .   0
# 5 chr1 16220 16221 1  .  -1 -1 .  .  .   0
# 6 chr1 16221 16222 1  .  -1 -1 .  .  .   0

# %%
intersect$ov_non <- ifelse(intersect[, 6] == -1, 0, 1)

# %%
ggplot(intersect, aes(x = V4, y = ..count.., color = factor(ov_non))) +
  geom_line(stat = "bin", binwidth = 3000, position = "stack") +
  theme_minimal() +
  scale_color_manual(name = "Non-Overlap/Overlap",
                     values = cbPalette,
                     labels = c("Non-Overlap", "Overlap")) +
  labs(x = "Coverage", y = "Counts")
# Out:
# plot without title

# %%
cbPalette <- c( "#E69F00",  "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7")
ggplot(intersect, aes(x = V4, fill=factor(ov_non))) +
  geom_histogram(binwidth = 3000, position="stack")+
    theme_minimal()+
    scale_fill_manual(name="Non-Overlap/Overlap",values=cbPalette)+
    labs(x="Coverage",y="Counts")
# Out:
# plot without title

# %%
#Coverage higher than 300
high_coverage <- subset(intersect, intersect[, 4] > 300)

# %%
cbPalette <- c( "#E69F00",  "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7")
ggplot(high_coverage, aes(x = V4, fill=factor(ov_non))) +
  geom_histogram(binwidth = 3000, position="dodge")+
    theme_minimal()+
    scale_fill_manual(name="Non-Overlap/Overlap",values=cbPalette)+
    labs(x="Coverage",y="Counts")
# Out:
# plot without title

# %% [markdown]
# # Intersect A1 with h38 and with all annotations (maintaining all rows)

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_A1_h38_all_NA.bed", header=FALSE)

# %%
intersect$ov_non <- ifelse(intersect[, 12] == -1, 0, 1)

# %%
intersect_unique <- intersect %>%
    group_by(V9) %>%
    slice(which.max(V4))
head(intersect_unique)
# Out:
#   V1    V2        V3        V4    V5    V6        V7        V8
# 1 chr1   24253385  24253386  1972 chr1   24251429  24335724 Pachytene
# 2 chr1  179587691 179587692  4621 chr1  179585426 179591786 Pachytene
# 3 chr1  222475665 222475666   308 chr1  222471907 222489700 Prepachytene
# 4 chr10  28792830  28792831 20365 chr10  28789400  28795995 Pachytene
# 5 chr10  44998366  44998367   364 chr10  44997697  45000888 Pachytene
# 6 chr10  77770324  77770325 18503 chr10  77763999  77783913 Pachytene
#   V9           V10   V11   V12      V13      V14
# 1 1-p36-1107   84295 chr1  24251540 24254842 XLOC_008295
# 2 1-q25-2976    6360 .           -1       -1 .
# 3 1-q41-289    17793 .           -1       -1 .
# 4 10-p11-10777  6595 chr10 28789311 28796050 LINC00837
# 5 10-q11-242    3191 chr10 44993932 45000803 ZNF22-AS1
# 6 10-q22-16903 19914 chr10 77766383 77773595 XLOC_016165

# %%
intersect_unique$ov_non <- ifelse(intersect_unique[, 12] == -1, 0, 1)
head(intersect_unique)
# Out:
#   V1    V2        V3        V4    V5    V6        V7        V8
# 1 chr1   24253385  24253386  1972 chr1   24251429  24335724 Pachytene
# 2 chr1  179587691 179587692  4621 chr1  179585426 179591786 Pachytene
# 3 chr1  222475665 222475666   308 chr1  222471907 222489700 Prepachytene
# 4 chr10  28792830  28792831 20365 chr10  28789400  28795995 Pachytene
# 5 chr10  44998366  44998367   364 chr10  44997697  45000888 Pachytene
# 6 chr10  77770324  77770325 18503 chr10  77763999  77783913 Pachytene
#   V9           V10   V11   V12      V13      V14         ov_non
# 1 1-p36-1107   84295 chr1  24251540 24254842 XLOC_008295 1
# 2 1-q25-2976    6360 .           -1       -1 .           0
# 3 1-q41-289    17793 .           -1       -1 .           0
# 4 10-p11-10777  6595 chr10 28789311 28796050 LINC00837   1
# 5 10-q11-242    3191 chr10 44993932 45000803 ZNF22-AS1   1
# 6 10-q22-16903 19914 chr10 77766383 77773595 XLOC_016165 1

# %%
cbPalette <- c( "#E69F00",  "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7")
ggplot(intersect_unique, aes(x = V4, fill=factor(ov_non))) +
  geom_histogram(binwidth = 3000, position="stack")+
    theme_minimal()+
    scale_fill_manual(name="Non-Overlap/Overlap",values=cbPalette)+
    labs(x="Coverage",y="Counts")
# Out:
# plot without title

# %%
ggplot(intersect_unique, aes(x = V4, y = ..count.., color = factor(ov_non))) +
  geom_line(stat = "bin", binwidth = 3000, position = "stack") +
  theme_minimal() +
  scale_color_manual(name = "Non-Overlap/Overlap",
                     values = cbPalette,
                     labels = c("Non-Overlap", "Overlap")) +
  labs(x = "Coverage", y = "Counts")
# Out:
# plot without title

# %%
filtered_df <- subset(intersect_unique, intersect_unique[, 8] == "Pachytene")
head(filtered_df)
# Out:
#   V1    V2        V3        V4    V5    V6        V7        V8
# 1 chr1   24253385  24253386  1972 chr1   24251429  24335724 Pachytene
# 2 chr1  179587691 179587692  4621 chr1  179585426 179591786 Pachytene
# 3 chr10  28792830  28792831 20365 chr10  28789400  28795995 Pachytene
# 4 chr10  44998366  44998367   364 chr10  44997697  45000888 Pachytene
# 5 chr10  77770324  77770325 18503 chr10  77763999  77783913 Pachytene
# 6 chr10  83561171  83561172   190 chr10  83560992  83565126 Pachytene
#   V9           V10   V11   V12      V13      V14         ov_non
# 1 1-p36-1107   84295 chr1  24251540 24254842 XLOC_008295 1
# 2 1-q25-2976    6360 .           -1       -1 .           0
# 3 10-p11-10777  6595 chr10 28789311 28796050 LINC00837   1
# 4 10-q11-242    3191 chr10 44993932 45000803 ZNF22-AS1   1
# 5 10-q22-16903 19914 chr10 77766383 77773595 XLOC_016165 1
# 6 10-q22-295    4134 chr10 83560977 83562666 XLOC_020068 1

# %%
ggplot(filtered_df, aes(x = V4, y = ..count.., color = factor(ov_non))) +
  geom_line(stat = "bin", binwidth = 3000, position = "stack") +
  theme_minimal() +
  scale_color_manual(name = "Non-Overlap/Overlap",
                     values = cbPalette,
                     labels = c("Non-Overlap", "Overlap")) +
  labs(x = "Coverage", y = "Counts") +
ggtitle("Pachytene cells")
# Out:
# plot without title

# %%
ggplot(intersect_unique, aes(x = V4, y = ..count.., color = factor(ov_non), linetype = V8)) +
  geom_line(stat = "bin", binwidth = 3000, position = "stack") +
  theme_minimal() +
  scale_color_manual(name = "Non-Overlap/Overlap",
                     values = cbPalette,
                     labels = c("Non-Overlap", "Overlap")) +
  scale_linetype_manual(name = "Cell Type", values = c( "dashed","solid","dotted")) +
  labs(x = "Coverage", y = "Counts") +
  guides(color = guide_legend(reverse = TRUE))
# Out:
# plot without title

# %%
head(intersect_unique)
# Out:
#   V1    V2        V3        V4    V5    V6        V7        V8
# 1 chr1   24253385  24253386  1972 chr1   24251429  24335724 Pachytene
# 2 chr1  179587691 179587692  4621 chr1  179585426 179591786 Pachytene
# 3 chr1  222475665 222475666   308 chr1  222471907 222489700 Prepachytene
# 4 chr10  28792830  28792831 20365 chr10  28789400  28795995 Pachytene
# 5 chr10  44998366  44998367   364 chr10  44997697  45000888 Pachytene
# 6 chr10  77770324  77770325 18503 chr10  77763999  77783913 Pachytene
#   V9           V10   V11   V12      V13      V14         ov_non
# 1 1-p36-1107   84295 chr1  24251540 24254842 XLOC_008295 1
# 2 1-q25-2976    6360 .           -1       -1 .           0
# 3 1-q41-289    17793 .           -1       -1 .           0
# 4 10-p11-10777  6595 chr10 28789311 28796050 LINC00837   1
# 5 10-q11-242    3191 chr10 44993932 45000803 ZNF22-AS1   1
# 6 10-q22-16903 19914 chr10 77766383 77773595 XLOC_016165 1

# %%
cbPalette <- c("#56B4E9", "#E69F00",  "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7")
ggplot(intersect_unique, aes(x=V4,fill = V8))+
    geom_histogram(bins=25)+
    theme_minimal()+
    scale_fill_manual(name="Type",values=cbPalette)+
    labs(x="Coverage",y="Counts")
# Out:
# plot without title

# %%
no_annotated<-filter(intersect_unique, V12 == -1)
arrange(no_annotated, desc(V4))
# Out:
#     V1    V2        V3        V4    V5    V6        V7        V8
# 1   chr7   56493595  56493596 38063 chr7   56483439  56497285 Pachytene
# 2   chr19  34815183  34815184 23907 chr19  34810543  34832869 Pachytene
# 3   chr15 101763150 101763151 20816 chr15 101746506 101776564 Pachytene
# 4   chr22  37364690  37364691 16278 chr22  37352189  37371722 Pachytene
# 5   chr15  99792256  99792257 12653 chr15  99786705  99806909 Pachytene
# 6   chr6   33886403  33886404  8675 chr6   33867505  33892451 Pachytene
# 7   chr14  88146180  88146181  7612 chr14  88132918  88160591 Pachytene
# 8   chr2  110700260 110700261  6916 chr2  110678284 110716605 Pachytene
# 9   chr21  44490890  44490891  6732 chr21  44468861  44494212 Pachytene
# 10  chr18  11661057  11661058  6345 chr18  11648847  11670163 Pachytene
# 11  chr6   39112479  39112480  6252 chr6   39104063  39115071 Pachytene
# 12  chr19  34853058  34853059  6104 chr19  34833109  34855304 Pachytene
# ...

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_A1_h38_non.bed", header=FALSE)

# %%
head(intersect)
# Out:
#   V1   V2    V3    V4
# 1 chr1 16216 16217 1
# 2 chr1 16217 16218 1
# 3 chr1 16218 16219 1
# 4 chr1 16219 16220 1
# 5 chr1 16220 16221 1
# 6 chr1 16221 16222 1

# %%
nrow(intersect)
# Out:
# [1] 122302238

# %%
ggplot(intersect, aes(x = V4, y = ..count..)) +
  geom_line(stat = "bin", binwidth = 3000, position = "stack") +
  theme_minimal() +
  labs(x = "Coverage", y = "Counts")
# Out:
# plot without title

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_A2_h38.bed", header=FALSE)

# %%
length(unique(intersect$V9))
# Out:
# [1] 182

# %% [markdown]
# # Intersect A2 unique with h38 precursors and not annotated cells

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_A2_h38_notanotated.bed", header=FALSE)

# %%
length(unique(intersect$V9))
# Out:
# [1] 127

# %% [markdown]
# # Intersect A2 unique with h38 precursors and all annotations

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_A2_h38_all.bed", header=FALSE)

# %%
length(unique(intersect$V9))
# Out:
# [1] 153

# %% [markdown]
# # Intersect A3 unique with h38 precursors

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_A3_h38.bed", header=FALSE)

# %%
length(unique(intersect$V9))
# Out:
# [1] 179

# %% [markdown]
# A total of 179/182 precursors overlap at least once

# %% [markdown]
# # Intersect A3 unique reads with h38 precursors and not annotated cells

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_A3_h38_notanotated.bed", header=FALSE)

# %%
length(unique(intersect$V9))
# Out:
# [1] 118

# %% [markdown]
# A total of 118 precursors are annotated in a position

# %% [markdown]
# # Intersect A3 unique reads with h38 precursors and all annotation

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_A3_h38_all.bed", header=FALSE)

# %%
length(unique(intersect$V9))
# Out:
# [1] 146

# %% [markdown]
# # Intersect Hum1 unique with h38 precursors

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_Hum1_h38.bed", header=FALSE)

# %%
length(unique(intersect$V9))
# Out:
# [1] 179

# %% [markdown]
# # Intersect Hum1 unique with h38 precursors and not annotated testis

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_Hum1_h38_notanotated.bed", header=FALSE)

# %%
length(unique(intersect$V9))
# Out:
# [1] 105

# %% [markdown]
# # Intersecr Hum1 unique with h38 precursors and all annotation

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_Hum1_h38_all.bed", header=FALSE)

# %%
length(unique(intersect$V9))
# Out:
# [1] 134

# %%
intersect_unique <- intersect %>%
    group_by(V9) %>%
    slice(which.max(V4))

# %%
df_sorted <- arrange(intersect_unique, desc(V4))
head(df_sorted)
nrow(df_sorted)
# Out:
#   V1    V2        V3        V4    V5    V6        V7        V8
# 1 chr19  16039219  16039220 14071 chr19  16033653  16041254 Pachytene
# 2 chr6   40378573  40378574  8829 chr6   40378336  40379885 Pachytene
# 3 chr19  19747674  19747675  5567 chr19  19741552  19754992 Pachytene
# 4 chr10  28791820  28791821  5444 chr10  28789400  28795995 Pachytene
# 5 chr6   29531373  29531374  2558 chr6   29529419  29533568 Pachytene
# 6 chr2  110678558 110678559  2430 chr2  110678284 110716605 Pachytene
#   V9           V10   V11   V12       V13       V14
# 1 19-p13-25455  7601 chr19  16033713  16042135 LINC00905
# 2 pi-TDRG1      1549 chr6   40378337  40379893 TDRG1
# 3 19-p13-6652  13440 chr19  19745229  19753672 LOC101060187
# 4 10-p11-10777  6595 chr10  28789311  28796050 LINC00837
# 5 6-p22-5808    4149 chr6   29529406  29533568 LINC01015
# 6 2-q13-9453   38321 chr2  110678147 110692786 LOC105373554
# [1] 134

# %%
filter(intersect_unique, V9 == '7-p11-9381')
filter(intersect_unique, V9 == '19-q13-13274')
# Out:
#   V1   V2       V3       V4 V5   V6       V7       V8        V9         V10
# 1 chr7 56496392 56496393 37 chr7 56483439 56497285 Pachytene 7-p11-9381 13846
#   V11  V12      V13      V14
# 1 chr7 56496223 56497284 DKFZp434L192
#   V1    V2       V3       V4  V5    V6       V7       V8        V9
# 1 chr19 34817461 34817462 788 chr19 34810543 34832869 Pachytene 19-q13-13274
#   V10   V11   V12      V13      V14
# 1 22326 chr19 34816154 34832869 LINC01801

# %% [markdown]
# # Merge the Hum1 and A1 samples

# %%
setwd("~/piRNA/Workspaces/julia/piRNA/unique_mapping/unique_coverage/Hum1")
hum1<- read.table("Hum1_coverage.bed", header=FALSE)
head(hum1)
# Out:
#   V1   V2     V3     V4
# 1 chr1 494539 494540 1
# 2 chr1 494540 494541 1
# 3 chr1 494541 494542 1
# 4 chr1 494542 494543 1
# 5 chr1 494543 494544 1
# 6 chr1 494544 494545 1

# %%
nrow(hum1)
# Out:
# [1] 9006067

# %%
setwd("~/piRNA/Workspaces/julia/zamore_lab/coverage")
A1<- read.table("A1_coverage.bed", header=FALSE)

# %%
nrow(A1)
# Out:
# [1] 125058114

# %%
human_samples<-rbind(hum1,A1)

# %%
nrow(human_samples)
# Out:
# [1] 134064181

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
write.table(human_samples, file = "human_samples.bed", quote=FALSE, sep="\t", row.names = FALSE, col.names=FALSE)

# %% [markdown]
# # Intersect Hum1 + A1 to h38 precursors

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_human_h38.bed", header=FALSE)
length(unique(intersect$V9))

# %%
head(intersect)
# Out:
#     V1   V2     V3     V4  V5  V6  V7  V8  V9  V10
# 1   chr1 494539 494540 1   .   -1  -1  .   .   .
# 2   chr1 494540 494541 1   .   -1  -1  .   .   .
# 3   chr1 494541 494542 1   .   -1  -1  .   .   .
# 4   chr1 494542 494543 1   .   -1  -1  .   .   .
# 5   chr1 494543 494544 1   .   -1  -1  .   .   .
# 6   chr1 494544 494545 1   .   -1  -1  .   .   .
# 7   chr1 494545 494546 1   .   -1  -1  .   .   .
# 8   chr1 494546 494547 1   .   -1  -1  .   .   .
# 9   chr1 494547 494548 1   .   -1  -1  .   .   .
# 10  chr1 494548 494549 1   .   -1  -1  .   .   .
# 11  chr1 494549 494550 1   .   -1  -1  .   .   .
# 12  chr1 494550 494551 1   .   -1  -1  .   .   .
# 13  chr1 494551 494552 1   .   -1  -1  .   .   .
# 14  chr1 494552 494553 1   .   -1  -1  .   .   .
# 15  chr1 494553 494554 1   .   -1  -1  .   .   .
# 16  chr1 494554 494555 1   .   -1  -1  .   .   .
# 17  chr1 494555 494556 1   .   -1  -1  .   .   .
# 18  chr1 494556 494557 1   .   -1  -1  .   .   .
# ...

# %%
setwd("~/piRNA/Workspaces/julia/lnc")
intersect<- read.table("intersect_human_h38_all.bed", header=FALSE)
length(unique(intersect$V9))
# Out:
# [1] 183

# %%
head(intersect)
# Out:
#   V1   V2     V3     V4 V5 V6 V7 V8 V9 V10 V11 V12 V13 V14
# 1 chr1 494539 494540 1  .  -1 -1 .  .  .   .   -1  -1  .
# 2 chr1 494540 494541 1  .  -1 -1 .  .  .   .   -1  -1  .
# 3 chr1 494541 494542 1  .  -1 -1 .  .  .   .   -1  -1  .
# 4 chr1 494542 494543 1  .  -1 -1 .  .  .   .   -1  -1  .
# 5 chr1 494543 494544 1  .  -1 -1 .  .  .   .   -1  -1  .
# 6 chr1 494544 494545 1  .  -1 -1 .  .  .   .   -1  -1  .

# %%
intersect_unique <- intersect %>%
    group_by(V9) %>%
    slice(which.max(V4))

# %%
head(intersect_unique)
nrow(intersect_unique)
# Out:
#   V1    V2        V3        V4    V5    V6        V7        V8
# 1 chr17  76561161  76561162 45111 .            -1        -1 .
# 2 chr1   24253385  24253386  1972 chr1   24251429  24335724 Pachytene
# 3 chr1  179587691 179587692  4621 chr1  179585426 179591786 Pachytene
# 4 chr1  222475665 222475666   308 chr1  222471907 222489700 Prepachytene
# 5 chr10  28792830  28792831 20365 chr10  28789400  28795995 Pachytene
# 6 chr10  44998366  44998367   364 chr10  44997697  45000888 Pachytene
#   V9           V10   V11   V12      V13      V14
# 1 .            .     .           -1       -1 .
# 2 1-p36-1107   84295 chr1  24251540 24254842 XLOC_008295
# 3 1-q25-2976   6360  .           -1       -1 .
# 4 1-q41-289    17793 .           -1       -1 .
# 5 10-p11-10777 6595  chr10 28789311 28796050 LINC00837
# 6 10-q11-242   3191  chr10 44993932 45000803 ZNF22-AS1
# [1] 183

# %%
no_annotated<-filter(intersect_unique, V12 == -1)

# %%
head(no_annotated)
nrow(no_annotated)
# Out:
#   V1    V2        V3        V4    V5    V6        V7        V8
# 1 chr17  76561161  76561162 45111 .            -1        -1 .
# 2 chr1  179587691 179587692  4621 chr1  179585426 179591786 Pachytene
# 3 chr1  222475665 222475666   308 chr1  222471907 222489700 Prepachytene
# 4 chr10  87237437  87237438    44 chr10  87201504  87316625 Prepachytene
# 5 chr12   3475854   3475855  3156 chr12   3461569   3491470 Pachytene
# 6 chr12   3455953   3455954   689 chr12   3437399   3461498 Pachytene
#   V9          V10    V11 V12 V13 V14
# 1 .           .      .   -1  -1  .
# 2 1-q25-2976  6360   .   -1  -1  .
# 3 1-q41-289   17793  .   -1  -1  .
# 4 10-q23-1174 115121 .   -1  -1  .
# 5 12-p13-6069 29901  .   -1  -1  .
# 6 12-p13-836  24099  .   -1  -1  .
# [1] 119
